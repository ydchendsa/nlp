# %%
import re
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import scipy as sc
from scipy import stats
import os

# %%
train = pd.read_csv("train.csv")
train.head()
# Out:
#         text_id                                          full_text  cohesion  \
# 0  0016926B079C  I think that students would benefit from learn...       3.5
# 1  0022683E9EA5  When a problem is a change you have to let it ...       2.5
# 2  00299B378633  Dear, Principal\n\nIf u change the school poli...       3.0
# 3  003885A45F42  The best time in life is when you become yours...       4.5
# 4  0049B1DF5CCC  Small act of kindness can impact in other peop...       2.5
#
#    syntax  vocabulary  phraseology  grammar  conventions
# 0     3.5         3.0          3.0      4.0          3.0
# 1     2.5         3.0          2.0      2.0          2.5
# 2     3.5         3.0          3.0      3.0          2.5
# 3     4.5         4.5          4.5      4.0          5.0
# 4     3.0         3.0          3.0      2.5          2.5

# %%
train['full_text'][3].split("\n")
# Out:
# ['The best time in life is when you become yourself. I agree that the greatest accomplishment, is when you be yourself in a world that constantly trying to make you something else. Because you make your own choices, you become more happy, and you respect others.',
#  '',
# ...

# %%
total = []
for i, n in enumerate(train['full_text']):
    for j in n.split("\n"):
        temp = []
        if j == '':
            continue
        temp.append(j)
        temp.extend([train['text_id'][i],train["cohesion"][i], train["syntax"][i],train["vocabulary"][i],train["phraseology"][i],
                    train["grammar"][i],train["conventions"][i]])
        total.append(temp)

# %%
total
# Out:
# [["I think that students would benefit from learning at home,because they wont have to change and get up early in the morning to shower and do there hair. taking only classes helps them because at there house they'll be pay more attention. they will be comfortable at home.",
#   '0016926B079C',
#   3.5,
#   3.5,
#   3.0,
#   3.0,
#   4.0,
#   3.0],
#  ["The hardest part of school is getting ready. you wake up go brush your teeth and go to your closet and look at your cloths. after you think you picked a outfit u go look in the mirror and youll either not like it or you look and see a stain. Then you'll have to change. with the online classes you can wear anything and stay home and you wont need to stress about what to wear.",
#   '0016926B079C',
#   3.5,
#   3.5,
#   3.0,
#   3.0,
#   4.0,
#   3.0],
# ...

# %%
train = pd.DataFrame(total)

# %%
train.columns = ['full_text', 'text_id', 'cohesion', 'syntax','vocabulary','phraseology','grammar','conventions']

# %%
train["full_text"][0].splitlines()
# Out:
# ["I think that students would benefit from learning at home,because they wont have to change and get up early in the morning to shower and do there hair. taking only classes helps them because at there house they'll be pay more attention. they will be comfortable at home."]

# %%
train
# Out:
#                                                full_text       text_id  \
# 0      I think that students would benefit from learn...  0016926B079C
# 1      The hardest part of school is getting ready. y...  0016926B079C
# 2      most students usually take showers before scho...  0016926B079C
# 3      when your home your comfortable and you pay at...  0016926B079C
# 4      When a problem is a change you have to let it ...  0022683E9EA5
# ...                                                  ...           ...
# 21804  First, people need to have the idea that after...  FFED00D6E0BD
# 21805  Secondly, everything depends in how positive p...  FFED00D6E0BD
# 21806  Finally, they always need to keep in mind that...  FFED00D6E0BD
# 21807  they need to have the power to stop themselves...  FFED00D6E0BD
# 21808  In conclusion, there have been nothing that ca...  FFED00D6E0BD
#
#        cohesion  syntax  vocabulary  phraseology  grammar  conventions
# ...

# %%
train.to_csv("train_20000.csv")

# %%
test = pd.read_csv("test.csv")
test.head()
# Out:
#         text_id                                          full_text
# 0  0000C359D63E  when a person has no experience on a job their...
# 1  000BAD50D026  Do you think students would benefit from being...
# 2  00367BB2546B  Thomas Jefferson once states that "it is wonde...

# %%
#final = pd.read_csv("sample_submission.csv")
#final

# %% [markdown]
# ### EDA: Getting to know our data

# %%
#add a new column to reflect the length of article
length = []
for i in train['full_text']:
    leng = len(i.split())
    length.append(leng)

# %%
train['full_text'] = train["full_text"].replace(re.compile(r'[\n\r\t]'), ' ', regex=True)
test['full_text'] = test["full_text"].replace(re.compile(r'[\n\r\t]'), ' ', regex=True)

# %%
train['text_length']=length
train
# Out:
#                                                full_text       text_id  \
# 0      I think that students would benefit from learn...  0016926B079C
# 1      The hardest part of school is getting ready. y...  0016926B079C
# 2      most students usually take showers before scho...  0016926B079C
# 3      when your home your comfortable and you pay at...  0016926B079C
# 4      When a problem is a change you have to let it ...  0022683E9EA5
# ...                                                  ...           ...
# 21804  First, people need to have the idea that after...  FFED00D6E0BD
# 21805  Secondly, everything depends in how positive p...  FFED00D6E0BD
# 21806  Finally, they always need to keep in mind that...  FFED00D6E0BD
# 21807  they need to have the power to stop themselves...  FFED00D6E0BD
# 21808  In conclusion, there have been nothing that ca...  FFED00D6E0BD
#
#        cohesion  syntax  vocabulary  phraseology  grammar  conventions  \
# ...

# %%
des_df = train[['text_id','cohesion','syntax','vocabulary','vocabulary','grammar','conventions']]
des_df
# Out:
#             text_id  cohesion  syntax  vocabulary  vocabulary  grammar  \
# 0      0016926B079C       3.5     3.5         3.0         3.0      4.0
# 1      0016926B079C       3.5     3.5         3.0         3.0      4.0
# 2      0016926B079C       3.5     3.5         3.0         3.0      4.0
# 3      0016926B079C       3.5     3.5         3.0         3.0      4.0
# 4      0022683E9EA5       2.5     2.5         3.0         3.0      2.0
# ...             ...       ...     ...         ...         ...      ...
# 21804  FFED00D6E0BD       3.5     2.5         3.5         3.5      3.0
# 21805  FFED00D6E0BD       3.5     2.5         3.5         3.5      3.0
# 21806  FFED00D6E0BD       3.5     2.5         3.5         3.5      3.0
# 21807  FFED00D6E0BD       3.5     2.5         3.5         3.5      3.0
# 21808  FFED00D6E0BD       3.5     2.5         3.5         3.5      3.0
#
#        conventions
# 0              3.0
# 1              3.0
# 2              3.0
# 3              3.0
# ...

# %% [markdown]
# ### Statistical Description for Train Dataset

# %%
des_train = des_df.select_dtypes(['int','float']).describe().T
#des_train = des_train.set_index('index')
reset_train = des_df.select_dtypes(['int','float']).describe().T.reset_index(drop=False) 
reset_train.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_c1458_row0_col1, #T_c1458_row0_col4, #T_c1458_row0_col5, #T_c1458_row0_col6, #T_c1458_row0_col7, #T_c1458_row0_col8, #T_c1458_row1_col1, #T_c1458_row1_col4, #T_c1458_row1_col5, #T_c1458_row1_col6, #T_c1458_row1_col7, #T_c1458_row1_col8, #T_c1458_row2_col1, #T_c1458_row2_col3, #T_c1458_row2_col4, #T_c1458_row2_col6, #T_c1458_row2_col7, #T_c1458_row2_col8, #T_c1458_row3_col1, #T_c1458_row3_col3, #T_c1458_row3_col4, #T_c1458_row3_col6, #T_c1458_row3_col7, #T_c1458_row3_col8, #T_c1458_row4_col1, #T_c1458_row4_col2, #T_c1458_row4_col4, #T_c1458_row4_col5, #T_c1458_row4_col6, #T_c1458_row4_col7, #T_c1458_row4_col8, #T_c1458_row5_col1, #T_c1458_row5_col4, #T_c1458_row5_col5, #T_c1458_row5_col6, #T_c1458_row5_col7, #T_c1458_row5_col8 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_c1458_row0_col2 {
#   background-color: #62bb6d;
#   color: #f1f1f1;
# }
# #T_c1458_row0_col3 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# ...

# %%
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import plotly.graph_objs as go
import pandas as pd
import numpy as np

# %%
plot_rows=3
plot_cols=2
fig = make_subplots(rows=plot_rows, cols=plot_cols)

# %%
import nltk
from nltk.tokenize import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /Users/kkkkshi/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# sample_train = train['full_text'][:50]

text_tag = []
for i in train['full_text']:
    i = word_tokenize(i)
    pos_tagger = nltk.pos_tag(i)
    word_tag = []
    for j in pos_tagger:
        (word,tag) = j
        word_tag.append(tag)
    text_tag.append(word_tag)

# %%
import nltk
from nltk.data import load
nltk.download('tagsets')
tagdict = load('help/tagsets/upenn_tagset.pickle')
tagdict.keys()
# Out:
# [nltk_data] Downloading package tagsets to /Users/kkkkshi/nltk_data...
# [nltk_data]   Package tagsets is already up-to-date!
# dict_keys(['LS', 'TO', 'VBN', "''", 'WP', 'UH', 'VBG', 'JJ', 'VBZ', '--', 'VBP', 'NN', 'DT', 'PRP', ':', 'WP$', 'NNPS', 'PRP$', 'WDT', '(', ')', '.', ',', '``', '$', 'RB', 'RBR', 'RBS', 'VBD', 'IN', 'FW', 'RP', 'JJR', 'JJS', 'PDT', 'MD', 'VB', 'WRB', 'NNP', 'EX', 'NNS', 'SYM', 'CC', 'CD', 'POS'])

# %%
tags = list(tagdict.keys())
tags.append("#")
tags
# Out:
# ['LS',
#  'TO',
#  'VBN',
#  "''",
#  'WP',
#  'UH',
#  'VBG',
#  'JJ',
#  'VBZ',
#  '--',
#  'VBP',
#  'NN',
#  'DT',
#  'PRP',
#  ':',
#  'WP$',
#  'NNPS',
#  'PRP$',
#  'WDT',
#  '(',
#  ')',
#  '.',
#  ',',
#  '``',
#  '$',
#  'RB',
#  'RBR',
#  'RBS',
#  'VBD',
#  'IN',
#  'FW',
#  'RP',
#  'JJR',
#  'JJS',
#  'PDT',
#  'MD',
#  'VB',
#  'WRB',
#  'NNP',
#  'EX',
#  'NNS',
#  'SYM',
#  'CC',
#  'CD',
#  'POS',
#  '#']

# %%
#list(tagdict.keys())
freq = pd.DataFrame(index=range(0,len(train)),columns=tags)
freq.iloc[:] = 0
freq = freq.astype('int')

# %%
from collections import Counter
d = []
for i in text_tag:
    d.append(Counter(i))

# %%
for i in range(len(train)):
    for key, value in d[i].items():
        freq[key][i] = value

# %%
verb = ["VB","VBG","VBD","VBN","VBP","VBZ"]
wh = ["WDT","WP","WRB","PDT","DT","WP$"] #determiner
connection = ["UH","RP","TO","IN","CC","MD","EX"]
adb = ["RB","RBR","RBS"]
pronoun = ["POS","PRP","PRP$"]
noun = ["NN","NNS","NNP","NNPS","LS"]
adj = ["JJ","JJR","JJS"]
fw = ["FW"] #foreign word
number = ['CD'] #number
punc = ["''","--","(",")",".",",","``","$","#","SYM"]

word_type = [verb,wh,connection,adb,pronoun, noun,adj,fw,number,punc]

# %%
#df['Fruit Total']= df.iloc[:, -4:-1].sum(axis=1)
train['verb'] = freq[verb].sum(axis=1)
train['wh'] = freq[wh].sum(axis=1)
train['connection'] = freq[connection].sum(axis=1)
train['adb'] = freq[adb].sum(axis=1)
train['pronoun'] = freq[pronoun].sum(axis=1)
train['noun'] = freq[noun].sum(axis=1)
train['adj'] = freq[adj].sum(axis=1)
train['fw'] = freq[fw].sum(axis=1)
train['number'] = freq[number].sum(axis=1)
train['punc'] = freq[punc].sum(axis=1)

# %%
train
# Out:
#                                                full_text       text_id  \
# 0      I think that students would benefit from learn...  0016926B079C
# 1      The hardest part of school is getting ready. y...  0016926B079C
# 2      most students usually take showers before scho...  0016926B079C
# 3      when your home your comfortable and you pay at...  0016926B079C
# 4      When a problem is a change you have to let it ...  0022683E9EA5
# ...                                                  ...           ...
# 21804  First, people need to have the idea that after...  FFED00D6E0BD
# 21805  Secondly, everything depends in how positive p...  FFED00D6E0BD
# 21806  Finally, they always need to keep in mind that...  FFED00D6E0BD
# 21807  they need to have the power to stop themselves...  FFED00D6E0BD
# 21808  In conclusion, there have been nothing that ca...  FFED00D6E0BD
#
#        cohesion  syntax  vocabulary  phraseology  grammar  conventions  \
# ...

# %%
import gensim
# Out:
# /Users/kkkkshi/opt/anaconda3/lib/python3.9/site-packages/requests/__init__.py:102: RequestsDependencyWarning:
#
# urllib3 (1.26.9) or chardet (5.0.0)/charset_normalizer (2.0.4) doesn't match a supported version!

# %%
text = []
for i in train.full_text:
    j = word_tokenize(i)
    text.append(j)

# %%
len(text)
# Out:
# 21809

# %%
word2vec = gensim.models.Word2Vec(text, vector_size=500, window=10,min_count=1)

# %%
word2vec.wv.key_to_index
# Out:
# {'to': 0,
#  '.': 1,
#  ',': 2,
#  'the': 3,
#  'and': 4,
#  'you': 5,
#  'a': 6,
#  'that': 7,
#  'is': 8,
#  'in': 9,
#  'they': 10,
#  'of': 11,
#  'have': 12,
#  'be': 13,
#  'I': 14,
#  'can': 15,
#  'it': 16,
#  'do': 17,
#  'for': 18,
#  'because': 19,
#  'are': 20,
#  'not': 21,
#  'people': 22,
#  'school': 23,
#  'or': 24,
#  'students': 25,
#  'with': 26,
#  'will': 27,
#  'your': 28,
#  'we': 29,
#  'their': 30,
#  "n't": 31,
#  'more': 32,
#  'if': 33,
#  'what': 34,
#  'time': 35,
#  'good': 36,
#  'get': 37,
#  'my': 38,
#  'on': 39,
#  'work': 40,
#  'but': 41,
#  'like': 42,
#  'want': 43,
#  'them': 44,
#  'life': 45,
#  'would': 46,
#  'help': 47,
#  'make': 48,
#  'i': 49,
#  'at': 50,
#  'when': 51,
#  'about': 52,
#  'this': 53,
#  'think': 54,
#  "'s": 55,
#  'some': 56,
#  'so': 57,
#  'all': 58,
#  'from': 59,
#  'was': 60,
#  'how': 61,
#  'one': 62,
#  'other': 63,
#  'something': 64,
#  'there': 65,
#  'know': 66,
#  'need': 67,
#  'should': 68,
# ...

# %%
def doc_vec(doc):
    doc_vector = []
    for i in doc:
        word_vec = []
        for j in i:
            if j in word2vec.wv.index_to_key:
                vec = word2vec.wv.get_vector(j)
                word_vec.append(vec)
        doc_vec = np.mean(word_vec,axis=0)
        doc_vector.append(doc_vec)
    return doc_vector

# %%
vector_list=[]
text_df = pd.DataFrame({'text':text})
text_df['doc_vec'] = text_df.apply(doc_vec)
# Out:
# /Users/kkkkshi/opt/anaconda3/lib/python3.9/site-packages/numpy/core/fromnumeric.py:3440: RuntimeWarning:
#
# Mean of empty slice.
#
# /Users/kkkkshi/opt/anaconda3/lib/python3.9/site-packages/numpy/core/_methods.py:189: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %%
x_train = np.asarray(text_df['doc_vec'].to_list())
# Out:
# /var/folders/14/844220wn4s38k_w_yvhf0wk00000gn/T/ipykernel_9269/4027050463.py:1: VisibleDeprecationWarning:
#
# Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.

# %%
x_train.shape
# Out:
# (21809,)

# %%
#x_train = x_train.reshape(x_train.shape[0],x_train.shape[1],1)

# %%
y_train = np.asarray(train[['cohesion','syntax','vocabulary','phraseology','grammar','conventions']])

# %%
y_train.shape
# Out:
# (21809, 6)

# %%
#from sklearn.ensemble import RandomForestRegressor
#regr = RandomForestRegressor(n_estimators=500,max_depth=10, random_state=0)
#regr.fit(x_train, y_train)

# %%
# regr.predict(x_train)
